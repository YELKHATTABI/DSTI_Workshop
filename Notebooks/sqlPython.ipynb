# %%
import pyodbc
import pandas as pd

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=DESKTOP-K9NOD7O;'
                      'Database=BikeStores;'
                      'Trusted_Connection=yes;')

# %%
cursor = conn.cursor()

# %%
cursor.execute("SELECT * from sales.stores")

# %%
list(cursor)
# Out:
# [(1, 'Santa Cruz Bikes', '(831) 476-4321', 'santacruz@bikes.shop', '3700 Portola Drive', 'Santa Cruz', 'CA', '95060'),
#  (2, 'Baldwin Bikes', '(516) 379-8888', 'baldwin@bikes.shop', '4200 Chestnut Lane', 'Baldwin', 'NY', '11432'),
#  (3, 'Rowlett Bikes', '(972) 530-5555', 'rowlett@bikes.shop', '8000 Fairway Avenue', 'Rowlett', 'TX', '75088')]

# %%
sql_query = pd.read_sql_query('SELECT * FROM sales.stores',conn)

# %%
sql_query
# Out:
#    store_id        store_name           phone                 email  \
# 0         1  Santa Cruz Bikes  (831) 476-4321  santacruz@bikes.shop
# 1         2     Baldwin Bikes  (516) 379-8888    baldwin@bikes.shop
# 2         3     Rowlett Bikes  (972) 530-5555    rowlett@bikes.shop
#
#                 street        city state zip_code
# 0   3700 Portola Drive  Santa Cruz    CA    95060
# 1   4200 Chestnut Lane     Baldwin    NY    11432
# 2  8000 Fairway Avenue     Rowlett    TX    75088

# %%
pwd
# Out:
# 'C:\\Users\\yassi\\DSTI_Workshop\\Notebooks'

# %%
df = pd.read_csv("../datasets/humaneressources.csv")

# %%
df
# Out:
#     DepartmentID                        Name  \
# 0              1                 Engineering
# 1              2                 Tool Design
# 2              3                       Sales
# 3              4                   Marketing
# 4              5                  Purchasing
# 5              6    Research and Development
# 6              7                  Production
# 7              8          Production Control
# 8              9             Human Resources
# 9             10                     Finance
# 10            11        Information Services
# 11            12            Document Control
# 12            13           Quality Assurance
# 13            14  Facilities and Maintenance
# 14            15      Shipping and Receiving
# 15            16                   Executive
#
#                                GroupName  Unnamed: 3
# 0               Research and Development         NaN
# 1               Research and Development         NaN
# ...

# %%
for index,row in df.iterrows():
    cursor.execute("INSERT INTO [BikeStores].[production].[HumanResources.DepartmentTest] (DepartmentID,Name,GroupName) values(?,?,?)", row.DepartmentID, row.Name, row.GroupName)
conn.commit()
cursor.close()

# %%
housing = pd.read_sql_query("SELECT * from dbo.housing",conn)

# %%
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
import plotly.express as px

# %%
housing.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
px.violin(data_frame=housing,y=['median_income',])
# Out:
# <div>                            <div id="865cbd0f-0a09-4cb2-9f8a-0ec1cd0eb8be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("865cbd0f-0a09-4cb2-9f8a-0ec1cd0eb8be")) {                    Plotly.newPlot(                        "865cbd0f-0a09-4cb2-9f8a-0ec1cd0eb8be",                        [{"alignmentgroup": "True", "box": {"visible": false}, "hovertemplate": "variable=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "scalegroup": "True", "showlegend": false, "type": "violin", "x": ["median_income", "median_income", "median_income", "median_income", "median_income", "median_income", "median_income", "median_income", "median_income", "median_income", "median_inc
# ...

# %%
df
# Out:
#     DepartmentID                        Name  \
# 0              1                 Engineering
# 1              2                 Tool Design
# 2              3                       Sales
# 3              4                   Marketing
# 4              5                  Purchasing
# 5              6    Research and Development
# 6              7                  Production
# 7              8          Production Control
# 8              9             Human Resources
# 9             10                     Finance
# 10            11        Information Services
# 11            12            Document Control
# 12            13           Quality Assurance
# 13            14  Facilities and Maintenance
# 14            15      Shipping and Receiving
# 15            16                   Executive
#
#                                GroupName  Unnamed: 3
# 0               Research and Development         NaN
# 1               Research and Development         NaN
# ...

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import chart_studio.plotly as py
import plotly.figure_factory as ff
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)         # initiate notebook for offline plot
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
pwd
# Out:
# '/Users/yelkhattabi/DSTI_Workshop/notebooks'

# %%
data = pd.read_csv("../datasets/winequality-red.csv")

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
fig = px.histogram(data_frame=data)

# %%
iplot(fig)
# Out:
# <div>                            <div id="cf425d50-557e-44d8-aec6-31f01df87bce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf425d50-557e-44d8-aec6-31f01df87bce")) {                    Plotly.newPlot(                        "cf425d50-557e-44d8-aec6-31f01df87bce",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "variable=fixed acidity<br>value=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "fixed acidity", "marker": {"color": "#636efa"}, "name": "fixed acidity", "offsetgroup": "fixed acidity", "orientation": "v", "showlegend": true, "type": "histogram", "x": [7.4, 7.8, 7.8, 11.2, 7.4, 7.4, 7.9, 7.3, 7.8, 7.5, 6.7, 7.5, 5.6, 7.8, 8.9, 8.9, 8.5, 8.1, 7.4, 7.9, 8.9, 7.6, 7.9, 8.5, 6.9, 6.3, 7.6, 7.9, 7.1, 7.8
# ...

# %%
px.box(data_frame=data, x="quality", y="alcohol")
# Out:
# <div>                            <div id="ab6a1d2a-cca2-4dd0-942d-1fc700d0d47a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab6a1d2a-cca2-4dd0-942d-1fc700d0d47a")) {                    Plotly.newPlot(                        "ab6a1d2a-cca2-4dd0-942d-1fc700d0d47a",                        [{"alignmentgroup": "True", "hovertemplate": "quality=%{x}<br>alcohol=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": [5, 5, 5, 6, 5, 5, 5, 7, 7, 5, 5, 5, 5, 5, 5, 5, 7, 5, 4, 6, 6, 5, 5, 5, 6, 5, 5, 5, 5, 6, 5, 6, 5, 6, 5, 6, 6, 7, 4, 5, 5, 4, 6, 5, 5, 4, 5, 5, 5, 5, 5, 6, 6, 5, 6, 5, 5, 5, 5, 6, 5, 5, 7, 5, 5, 5, 5, 5, 5, 6, 6, 5
# ...

# %%
px.scatter(data_frame=data, x="alcohol", y="quality")
# Out:
# <div>                            <div id="2834eb40-a46d-4218-9a81-d6d511896040" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2834eb40-a46d-4218-9a81-d6d511896040")) {                    Plotly.newPlot(                        "2834eb40-a46d-4218-9a81-d6d511896040",                        [{"hovertemplate": "alcohol=%{x}<br>quality=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scattergl", "x": [9.4, 9.8, 9.8, 9.8, 9.4, 9.4, 9.4, 10.0, 9.5, 10.5, 9.2, 10.5, 9.9, 9.1, 9.2, 9.2, 10.5, 9.3, 9.0, 9.2, 9.4, 9.7, 9.5, 9.4, 9.7, 9.3, 9.5, 9.5, 9.4, 9.8, 10.1, 10.6, 9.8, 9.4, 9.2, 9.6, 10.8, 9.7, 9.8, 10.5, 10.5, 9.3, 10.5, 10.3, 9.5, 13.1, 9.2, 9.5, 
# ...

# %%
data.columns.tolist()
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
from ipywidgets import widgets

# %%
data.columns.tolist()
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
x=widgets.Dropdown(
    description='X dimension',
    options=data.columns.tolist()
)
y=widgets.Dropdown(
    description='y dimension',
    options=data.columns.tolist()
)

# %%
x
# Out:
# Dropdown(description='X dimension', options=('fixed acidity', 'volatile acidity', 'citric acid', 'residual sug…

# %%
y
# Out:
# Dropdown(description='y dimension', index=6, options=('fixed acidity', 'volatile acidity', 'citric acid', 'res…

# %%
px.scatter(data_frame=data, 
           x=x.value, y=y.value,)
# Out:
# <div>                            <div id="fee1f331-5af6-4f4d-a922-63d01dd3102a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fee1f331-5af6-4f4d-a922-63d01dd3102a")) {                    Plotly.newPlot(                        "fee1f331-5af6-4f4d-a922-63d01dd3102a",                        [{"hovertemplate": "fixed acidity=%{x}<br>total sulfur dioxide=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scattergl", "x": [7.4, 7.8, 7.8, 11.2, 7.4, 7.4, 7.9, 7.3, 7.8, 7.5, 6.7, 7.5, 5.6, 7.8, 8.9, 8.9, 8.5, 8.1, 7.4, 7.9, 8.9, 7.6, 7.9, 8.5, 6.9, 6.3, 7.6, 7.9, 7.1, 7.8, 6.7, 6.9, 8.3, 6.9, 5.2, 7.8, 7.8, 8.1, 5.7, 7.3, 7.3, 8.8, 7.5, 8.1, 6.8, 4.6, 7.
# ...

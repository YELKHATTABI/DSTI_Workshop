# %% [markdown]
# # Python Data Structures
# ## Variables
#
# How to declare variables
# ```
# variable_name = value
# ```

# %%
greeting = "hello world"

# %% [markdown]
# a has a string as a value and does exist in our workspace
# To check what we have in our workspace you can use the command 'who'

# %%
who

# %% [markdown]
# To check the type of the variable we can use the function `type()`

# %%
type(greeting)

# %% [markdown]
# `greeting` is a string indeed
#
# We can declare variable of different types : int, float, bool ...

# %%
number = 29
Float_number = 2.4
boolean = False

# %%
type(number)

# %%
type(Float_number)

# %%
type(boolean)

# %%
another_number = 24

# %%
number = another_number

# %%
number

# %% [markdown]
# ## List
# list is a python datastructes, that is a sequence, mutable, and has an order

# %% [markdown]
# ### Creating an empty less

# %%
l = list()

# %%
l

# %%
l = []

# %%
l

# %% [markdown]
# ### Creating a list with elements

# %%
l = [25,2019,"data"]

# %%
l

# %% [markdown]
# ### Accessing list elements of a list

# %% [markdown]
# #### getting the number of elements in a list

# %%
len(l)

# %%
l[0]

# %%
l[1]

# %%
l[2]

# %%
#l[3]

# %%
l[-1]

# %%
l[-2]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Adding an element at the and of a list

# %%
l.append("monday")

# %%
len(l)

# %%
l

# %% [markdown]
# #### Adding an element at any position on a list

# %%
l.insert(2,"third position")

# %%
l

# %% [markdown]
# #### Removing an element from the end of a list

# %%
l.pop()

# %%
l

# %% [markdown]
# #### Removing an element from any position of a list

# %%
l.pop(1)

# %%
l

# %%
len(l)

# %% [markdown]
# ### Strings (very similar to list for indexation)

# %%
greeting

# %%
print(greeting)

# %%
greeting.capitalize()

# %%
greeting

# %%
greeting = greeting.capitalize()

# %%
greeting

# %%
shouting_greeting = greeting.upper()

# %%
shouting_greeting

# %%
shouting_greeting = shouting_greeting + " !"

# %%
shouting_greeting

# %%
shouting_greeting[0]

# %%
list(shouting_greeting)

# %%
shouting_greeting.split()

# %%
shouting_greeting.split("O")

# %%
comment ="Today is a beautiful day"

# %%
greeting + "! " + comment

# %% [markdown]
# #### Formatting strings

# %%
f" This is our greeting: {greeting} and a comment about the day {comment} plus a bonus list {l}"

# %%
Comments = F"""
This is our greeting: 
{greeting}
and a comment about the day
{comment} 
plus a bonus list: {l}

"""

# %%
print(Comments)

# %%
float_number = 123.25478

# %%
print(f"this is a number {float_number}")

# %%
print(f"this is a number {float_number:.2f}")

# %% [markdown]
# ## Dictionary

# %% [markdown]
# ### Creating an empty dictionnary

# %%
d = dict()

# %%
d

# %%
d = {}

# %%
type(d)

# %%
d = {"key":"value"}

# %%
d

# %%
d = {"name":"Nassim",
    "age":27,
    "address": "Paris"}

# %%
d

# %%
d["name"]

# %%
d["address"]

# %%
d.keys()

# %%
len(d)

# %%
d.values()

# %%
d.update({"Passion":"python"})

# %%
d

# %%
d["hobbies"] = ["Tennis","Chess"]

# %%
d

# %%
d

# %%
d.items()

# %%
d["hobbies"]

# %%
d["hobbies"][0]

# %%
d["hobbies"].append("Video games")

# %%
d

# %%
complementary_informations = {
    "Job" : "Data Analyst",
    "Favorite food" : "Pizza",
}

# %%
d.update(complementary_informations)

# %%
d

# %% [markdown]
# ## Tuple
# - Similar to lists (sequence, has order)
# - Immutable : you cannot add an element or remove an element from it, used mainly to store data that you don't want to modify

# %%
t = tuple()

# %%
t

# %%
len(t)

# %%
type(t)

# %%
t = ("a","b","a","c")

# %%
t[0]

# %%
t[1]

# %%
t[-1]

# %%
t[0] = "new element"

# %%
t.append("e")

# %%
t.pop()

# %%
t.index("a")

# %%
t[1:]

# %%
t

# %%
t[1:3]

# %%
t[1:4]

# %% [markdown]
# ## Set

# %%
s = set()

# %%
s.add(5)

# %%
s

# %%
s.add(5)

# %%
s

# %%
s.add(4)

# %%
s.add(484)

# %%
s.add(4)

# %%
s

# %%
s.pop()

# %%
s

# %%
s.remove(5)

# %%
s

# %%
s.add(5)

# %%
s

# %%
u = {3,5,4,2,45}

# %%
u

# %%
s.intersection(u)

# %%
s.union(u)

# %%
u.difference(s)

# %%
u.discard(45)
